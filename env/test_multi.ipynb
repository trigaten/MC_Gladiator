# %%
"""

Adapted from https://github.com/minerllabs/minerl/blob/dev/tests/multiagent_test.py
"""
from minerl.env.malmo import InstanceManager
import argparse
from pvpbox_specs import PvpBox

__author__ = "Sander Schulhoff"
__email__ = "sanderschulhoff@gmail.com"

class PvpBoxMultiAgent(PvpBox):
    def create_server_quit_producers(self):
        return []

if __name__ == '__main__':

    # Two agents in the same world!
    env_spec = PvpBoxMultiAgent(agent_count=2)

    # IF you want to use existing instances use this!
    # instances = [
    #     InstanceManager.add_existing_instance(9001),
    #     InstanceManager.add_existing_instance(9002)]
    instances = []

    env = env_spec.make(instances=instances)
    
    # make the agents move and stuff
    # iterate desired episodes
    # for r in range(10):
    #     env.reset()
    #     steps = 0

    #     done = False
    #     actor_names = env.task.agent_names
    #     while not done:
    #         steps += 1
    #         env.render()

    #         actions = env.action_space.no_op()
    #         for agent in actions:
    #             actions[agent]["forward"] = 0.1
    #             actions[agent]["attack"] = 1
    #             actions[agent]["camera"] = [0, 0.1]
    #         # actions = env.action_space.sample()

    #         # print(str(steps) + " actions: " + str(actions))

    #         obs, reward, done, info = env.step(actions)
            
            # print(obs)
# Out:
# /opt/anaconda3/envs/gladiator/lib/python3.9/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# /opt/anaconda3/envs/gladiator/lib/python3.9/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# /opt/anaconda3/envs/gladiator/lib/python3.9/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))
# /opt/anaconda3/envs/gladiator/lib/python3.9/runpy.py:127: RuntimeWarning: 'minerl.utils.process_watcher' found in sys.modules after import of package 'minerl.utils', but prior to execution of 'minerl.utils.process_watcher'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# /opt/anaconda3/envs/gladiator/lib/python3.9/runpy.py:127: RuntimeWarning: 'minerl.utils.process_watcher' found in sys.modules after import of package 'minerl.utils', but prior to execution of 'minerl.utils.process_watcher'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# MineRL agent is public, connect on port 58768 with Minecraft 1.11
# {'agent_0': {'pov': array([[[  0, 124, 124],
#         [  0, 124, 124],
#         [  0, 124, 124],
#         ...,
#         [  0, 113, 113],
#         [  0, 113, 113],
#         [  0, 113, 113]],
#
#        [[  0, 124, 124],
#         [  0, 124, 124],
#         [  0, 124, 124],
#         ...,
#         [  0, 113, 113],
#         [  0, 113, 113],
#         [  0, 113, 113]],
#
#        [[  0, 124, 124],
#         [  0, 124, 124],
#         [  0, 124, 124],
#         ...,
#         [  0, 113, 113],
#         [  0, 113, 113],
#         [  0, 113, 113]],
#
#        ...,
#
#        [[  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129],
#         ...,
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122]],
#
#        [[  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129],
#         ...,
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122]],
#
#        [[  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129],
#         ...,
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(5.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[111,  69,  31],
#         [111,  69,  31],
#         [111,  69,  31],
#         ...,
#         [111,  69,  31],
#         [113,  76,  37],
#         [113,  76,  37]],
#
#        [[111,  69,  31],
#         [111,  69,  31],
#         [111,  69,  31],
#         ...,
#         [111,  69,  31],
#         [113,  76,  37],
#         [113,  76,  37]],
#
#        [[111,  69,  31],
#         [111,  69,  31],
#         [111,  69,  31],
#         ...,
#         [111,  69,  31],
#         [113,  76,  37],
#         [113,  76,  37]],
#
#        ...,
#
#        [[ 86,  51,  20],
#         [ 86,  51,  20],
#         [ 86,  51,  20],
#         ...,
#         [ 89,  79,  65],
#         [ 89,  79,  65],
#         [ 89,  79,  65]],
#
#        [[ 86,  51,  20],
#         [ 86,  51,  20],
#         [ 86,  51,  20],
#         ...,
#         [ 89,  79,  65],
#         [ 89,  79,  65],
#         [ 89,  79,  65]],
#
#        [[ 86,  51,  20],
#         [ 86,  51,  20],
#         [ 86,  51,  20],
#         ...,
#         [ 89,  79,  65],
#         [ 89,  79,  65],
#         [ 89,  79,  65]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(5.), 'score': array(0), 'xp': array(0)}}}
# 0it [00:00, ?it/s]
# {'agent_0': {'pov': array([[[  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129],
#         ...,
#         [  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129]],
#
#        [[  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129],
#         ...,
#         [  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129]],
#
#        [[  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129],
#         ...,
#         [  0, 129, 129],
#         [  0, 129, 129],
#         [  0, 129, 129]],
#
#        ...,
#
#        [[ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         ...,
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122]],
#
#        [[ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         ...,
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122]],
#
#        [[ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         ...,
#         [ 52,  43, 122],
#         [ 52,  43, 122],
#         [ 52,  43, 122]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(5.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[111,  74,  35],
#         [111,  74,  35],
#         [111,  74,  35],
#         ...,
#         [111,  74,  35],
#         [107,  71,  29],
#         [107,  71,  29]],
#
#        [[111,  74,  35],
#         [111,  74,  35],
#         [111,  74,  35],
#         ...,
#         [111,  74,  35],
#         [107,  71,  29],
#         [107,  71,  29]],
#
#        [[111,  74,  35],
#         [111,  74,  35],
#         [111,  74,  35],
#         ...,
#         [111,  74,  35],
#         [107,  71,  29],
#         [107,  71,  29]],
#
#        ...,
#
#        [[169, 113,  53],
#         [169, 113,  53],
#         [169, 113,  53],
#         ...,
#         [102, 103,  75],
#         [102, 103,  75],
#         [102, 103,  75]],
#
#        [[169, 113,  53],
#         [169, 113,  53],
#         [169, 113,  53],
#         ...,
#         [102, 103,  75],
#         [102, 103,  75],
#         [102, 103,  75]],
#
#        [[169, 113,  53],
#         [169, 113,  53],
#         [169, 113,  53],
#         ...,
#         [102, 103,  75],
#         [102, 103,  75],
#         [102, 103,  75]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(5.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[ 76,  27,  27],
#         [ 76,  27,  27],
#         [ 76,  27,  27],
#         ...,
#         [113,  30,  85],
#         [113,  30,  85],
#         [113,  30,  85]],
#
#        [[ 76,  27,  27],
#         [ 76,  27,  27],
#         [ 76,  27,  27],
#         ...,
#         [113,  30,  85],
#         [113,  30,  85],
#         [113,  30,  85]],
#
#        [[ 76,  27,  27],
#         [ 76,  27,  27],
#         [ 76,  27,  27],
#         ...,
#         [113,  30,  85],
#         [113,  30,  85],
#         [113,  30,  85]],
#
#        ...,
#
#        [[ 86, 112,  53],
#         [ 86, 112,  53],
#         [ 75,  98,  46],
#         ...,
#         [116, 114,  52],
#         [118, 118,  50],
#         [121, 121,  51]],
#
#        [[ 86, 112,  53],
#         [ 75,  98,  46],
#         [ 92, 120,  57],
#         ...,
#         [113, 112,  53],
#         [116, 115,  53],
#         [118, 118,  50]],
#
#        [[ 75,  98,  46],
#         [ 92, 120,  57],
#         [ 92, 120,  57],
#         ...,
#         [110, 109,  49],
#         [113, 112,  53],
#         [116, 115,  53]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[195,  79,  37],
#         [195,  79,  37],
#         [195,  79,  37],
#         ...,
#         [198, 109,  93],
#         [198, 109,  93],
#         [198, 109,  93]],
#
#        [[195,  79,  37],
#         [195,  79,  37],
#         [195,  79,  37],
#         ...,
#         [198, 109,  93],
#         [198, 109,  93],
#         [198, 109,  93]],
#
#        [[195,  79,  37],
#         [195,  79,  37],
#         [195,  79,  37],
#         ...,
#         [198, 109,  93],
#         [198, 109,  93],
#         [198, 109,  93]],
#
#        ...,
#
#        [[149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71],
#         ...,
#         [149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71]],
#
#        [[149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71],
#         ...,
#         [149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71]],
#
#        [[149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71],
#         ...,
#         [149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(14.), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[171, 202, 255],
#         [171, 202, 255],
#         [171, 201, 255],
#         ...,
#         [140, 181, 255],
#         [141, 181, 255],
#         [168, 200, 255]],
#
#        [[155, 191, 255],
#         [154, 190, 255],
#         [171, 202, 255],
#         ...,
#         [141, 181, 255],
#         [168, 200, 255],
#         [168, 200, 255]],
#
#        [[156, 191, 255],
#         [155, 191, 255],
#         [155, 190, 255],
#         ...,
#         [168, 200, 255],
#         [168, 200, 255],
#         [168, 200, 255]],
#
#        ...,
#
#        [[ 80, 104,  49],
#         [ 77, 100,  47],
#         [ 77, 100,  47],
#         ...,
#         [127, 127,  33],
#         [129, 131,  37],
#         [134, 133,  41]],
#
#        [[ 87, 113,  53],
#         [ 77, 100,  47],
#         [ 94, 123,  57],
#         ...,
#         [125, 118,  33],
#         [127, 127,  33],
#         [130, 130,  37]],
#
#        [[ 87, 113,  53],
#         [101, 131,  61],
#         [101, 132,  62],
#         ...,
#         [122, 115,  33],
#         [125, 118,  33],
#         [128, 127,  34]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(9.73088), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[166,  80,  68],
#         [166,  80,  68],
#         [166,  80,  68],
#         ...,
#         [124,  38,  26],
#         [124,  38,  26],
#         [124,  38,  26]],
#
#        [[166,  80,  68],
#         [166,  80,  68],
#         [166,  80,  68],
#         ...,
#         [124,  38,  26],
#         [124,  38,  26],
#         [124,  38,  26]],
#
#        [[166,  80,  68],
#         [166,  80,  68],
#         [166,  80,  68],
#         ...,
#         [124,  38,  26],
#         [124,  38,  26],
#         [124,  38,  26]],
#
#        ...,
#
#        [[144,  62,  54],
#         [144,  62,  54],
#         [144,  62,  54],
#         ...,
#         [ 90,  33,  13],
#         [ 90,  33,  13],
#         [ 90,  33,  13]],
#
#        [[144,  62,  54],
#         [144,  62,  54],
#         [144,  62,  54],
#         ...,
#         [149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71]],
#
#        [[144,  62,  54],
#         [144,  62,  54],
#         [142,  59,  50],
#         ...,
#         [149,  98,  71],
#         [149,  98,  71],
#         [149,  98,  71]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.46176), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[171, 202, 255],
#         [171, 202, 255],
#         [171, 201, 255],
#         ...,
#         [140, 181, 255],
#         [141, 181, 255],
#         [168, 200, 255]],
#
#        [[155, 191, 255],
#         [171, 202, 255],
#         [171, 202, 255],
#         ...,
#         [141, 181, 255],
#         [168, 200, 255],
#         [168, 200, 255]],
#
#        [[156, 191, 255],
#         [155, 191, 255],
#         [155, 190, 255],
#         ...,
#         [168, 200, 255],
#         [168, 200, 255],
#         [168, 200, 255]],
#
#        ...,
#
#        [[ 75,  98,  46],
#         [ 86, 112,  52],
#         [ 72,  94,  44],
#         ...,
#         [157, 156,  53],
#         [156, 157,  62],
#         [155, 155,  60]],
#
#        [[ 86, 112,  52],
#         [ 86, 112,  52],
#         [ 72,  94,  44],
#         ...,
#         [147, 132,  37],
#         [157, 156,  53],
#         [155, 155,  60]],
#
#        [[ 92, 121,  56],
#         [ 83, 109,  51],
#         [ 86, 112,  52],
#         ...,
#         [147, 132,  37],
#         [147, 132,  37],
#         [156, 155,  51]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.46176), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[108, 136, 186],
#         [102, 121, 155],
#         [102, 121, 155],
#         ...,
#         [239, 110,  53],
#         [239, 110,  53],
#         [239, 110,  53]],
#
#        [[107, 135, 184],
#         [108, 135, 186],
#         [108, 136, 187],
#         ...,
#         [239, 110,  53],
#         [239, 110,  53],
#         [150,  49,  23]],
#
#        [[107, 134, 183],
#         [107, 135, 184],
#         [108, 135, 185],
#         ...,
#         [239, 110,  53],
#         [150,  49,  23],
#         [150,  49,  23]],
#
#        ...,
#
#        [[ 85, 111,  52],
#         [ 72,  95,  45],
#         [ 72,  95,  45],
#         ...,
#         [145,  61,  53],
#         [145,  61,  53],
#         [145,  61,  52]],
#
#        [[ 97, 127,  60],
#         [ 72,  95,  45],
#         [ 70,  91,  43],
#         ...,
#         [145,  61,  53],
#         [145,  61,  53],
#         [145,  61,  52]],
#
#        [[ 97, 127,  60],
#         [ 92, 120,  57],
#         [ 92, 120,  57],
#         ...,
#         [145,  61,  53],
#         [145,  61,  53],
#         [145,  61,  53]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.46176), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[171, 202, 255],
#         [171, 202, 255],
#         [171, 201, 255],
#         ...,
#         [140, 181, 255],
#         [141, 181, 255],
#         [168, 200, 255]],
#
#        [[155, 191, 255],
#         [154, 190, 255],
#         [171, 202, 255],
#         ...,
#         [141, 181, 255],
#         [168, 200, 255],
#         [168, 200, 255]],
#
#        [[156, 191, 255],
#         [155, 191, 255],
#         [155, 191, 255],
#         ...,
#         [168, 200, 255],
#         [168, 200, 255],
#         [168, 200, 255]],
#
#        ...,
#
#        [[ 81, 105,  49],
#         [ 99, 129,  60],
#         [ 83, 108,  51],
#         ...,
#         [156, 156,  58],
#         [156, 157,  54],
#         [157, 148,  42]],
#
#        [[102, 133,  62],
#         [ 83, 108,  51],
#         [ 92, 121,  56],
#         ...,
#         [156, 156,  58],
#         [157, 156,  58],
#         [156, 157,  54]],
#
#        [[ 87, 113,  53],
#         [ 72,  94,  44],
#         [ 81, 106,  50],
#         ...,
#         [157, 152,  55],
#         [157, 156,  58],
#         [157, 156,  58]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(7.1926394), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[109, 129, 165],
#         [109, 129, 165],
#         [109, 130, 165],
#         ...,
#         [110, 131, 170],
#         [110, 131, 170],
#         [154,  52,  24]],
#
#        [[133, 108,  28],
#         [113, 142, 194],
#         [109, 129, 165],
#         ...,
#         [110, 131, 169],
#         [109, 131, 169],
#         [154,  52,  24]],
#
#        [[156, 144,  62],
#         [133, 107,  28],
#         [113, 141, 194],
#         ...,
#         [109, 131, 169],
#         [109, 131, 169],
#         [154,  52,  24]],
#
#        ...,
#
#        [[ 76, 100,  47],
#         [108, 141,  66],
#         [108, 141,  66],
#         ...,
#         [171,  84,  72],
#         [171,  84,  72],
#         [171,  84,  72]],
#
#        [[108, 141,  66],
#         [108, 141,  66],
#         [ 66,  87,  41],
#         ...,
#         [168,  81,  69],
#         [171,  84,  72],
#         [171,  84,  72]],
#
#        [[108, 141,  66],
#         [ 66,  87,  41],
#         [ 72,  95,  45],
#         ...,
#         [168,  81,  69],
#         [171,  84,  72],
#         [171,  84,  72]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.46176), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[155, 191, 255],
#         [171, 202, 255],
#         [171, 202, 255],
#         ...,
#         [140, 181, 255],
#         [140, 181, 255],
#         [140, 181, 255]],
#
#        [[156, 191, 255],
#         [155, 191, 255],
#         [155, 191, 255],
#         ...,
#         [140, 181, 255],
#         [141, 181, 255],
#         [168, 200, 255]],
#
#        [[157, 192, 255],
#         [156, 192, 255],
#         [155, 191, 255],
#         ...,
#         [141, 181, 255],
#         [168, 200, 255],
#         [168, 200, 255]],
#
#        ...,
#
#        [[ 78, 101,  48],
#         [ 83, 108,  51],
#         [ 96, 125,  59],
#         ...,
#         [156, 151,  54],
#         [144, 127,  35],
#         [145, 124,  34]],
#
#        [[ 84, 110,  52],
#         [ 78, 101,  48],
#         [ 77, 101,  48],
#         ...,
#         [155, 155,  53],
#         [156, 151,  54],
#         [145, 124,  34]],
#
#        [[ 96, 125,  59],
#         [ 73,  96,  45],
#         [ 78, 102,  48],
#         ...,
#         [156, 156,  52],
#         [155, 155,  53],
#         [156, 150,  54]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(7.1926394), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[117, 146, 199],
#         [115, 136, 174],
#         [115, 137, 174],
#         ...,
#         [118, 155, 223],
#         [115, 138, 178],
#         [115, 138, 178]],
#
#        [[117, 146, 198],
#         [117, 146, 199],
#         [117, 146, 200],
#         ...,
#         [115, 138, 178],
#         [115, 138, 178],
#         [115, 138, 178]],
#
#        [[146, 134,  45],
#         [117, 145, 197],
#         [117, 146, 198],
#         ...,
#         [115, 138, 178],
#         [115, 138, 178],
#         [115, 138, 178]],
#
#        ...,
#
#        [[ 68,  89,  42],
#         [ 70,  91,  43],
#         [ 62,  81,  38],
#         ...,
#         [176,  89,  77],
#         [176,  89,  77],
#         [176,  89,  77]],
#
#        [[ 70,  91,  43],
#         [ 62,  81,  38],
#         [ 73,  96,  45],
#         ...,
#         [176,  89,  77],
#         [176,  89,  77],
#         [176,  89,  77]],
#
#        [[ 72,  94,  44],
#         [ 73,  95,  45],
#         [ 73,  95,  45],
#         ...,
#         [ 97,  21,  21],
#         [139,  63,  63],
#         [176,  89,  77]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(10.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[171, 201, 255],
#         [152, 189, 255],
#         [151, 188, 255],
#         ...,
#         [168, 200, 255],
#         [168, 200, 255],
#         [169, 200, 255]],
#
#        [[171, 201, 255],
#         [171, 201, 255],
#         [152, 189, 255],
#         ...,
#         [168, 200, 255],
#         [169, 200, 255],
#         [169, 200, 255]],
#
#        [[171, 202, 255],
#         [171, 202, 255],
#         [171, 201, 255],
#         ...,
#         [169, 200, 255],
#         [169, 200, 255],
#         [142, 182, 255]],
#
#        ...,
#
#        [[ 61,  79,  37],
#         [ 57,  74,  34],
#         [ 56,  73,  34],
#         ...,
#         [156, 152,  50],
#         [155, 155,  60],
#         [157, 156,  70]],
#
#        [[ 59,  77,  36],
#         [ 60,  78,  36],
#         [ 69,  90,  42],
#         ...,
#         [156, 152,  50],
#         [156, 152,  50],
#         [156, 156,  62]],
#
#        [[ 61,  80,  37],
#         [ 70,  91,  43],
#         [ 73,  95,  45],
#         ...,
#         [147, 131,  36],
#         [156, 152,  50],
#         [156, 152,  50]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(7.1926394), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[120, 152, 209],
#         [120, 152, 210],
#         [120, 152, 210],
#         ...,
#         [121, 144, 186],
#         [121, 144, 186],
#         [120, 157, 224]],
#
#        [[121, 143, 182],
#         [120, 152, 209],
#         [120, 152, 209],
#         ...,
#         [121, 144, 186],
#         [120, 157, 224],
#         [120, 157, 224]],
#
#        [[121, 143, 182],
#         [121, 143, 182],
#         [121, 143, 182],
#         ...,
#         [120, 157, 224],
#         [120, 157, 224],
#         [120, 157, 223]],
#
#        ...,
#
#        [[104,  88,  23],
#         [ 96,  77,  19],
#         [ 92,  85,  27],
#         ...,
#         [ 97,  21,  21],
#         [ 97,  21,  21],
#         [111,  23,  15]],
#
#        [[ 96,  78,  19],
#         [ 92,  72,  16],
#         [ 89,  82,  24],
#         ...,
#         [102,  25,  25],
#         [102,  25,  25],
#         [111,  23,  15]],
#
#        [[ 92,  72,  16],
#         [ 92,  71,  17],
#         [ 46,  60,  28],
#         ...,
#         [102,  25,  25],
#         [102,  25,  25],
#         [102,  25,  25]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(10.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[150, 187, 255],
#         [149, 187, 255],
#         [149, 187, 255],
#         ...,
#         [142, 182, 255],
#         [142, 182, 255],
#         [143, 182, 255]],
#
#        [[150, 188, 255],
#         [150, 187, 255],
#         [150, 187, 255],
#         ...,
#         [143, 182, 255],
#         [143, 183, 255],
#         [143, 183, 255]],
#
#        [[151, 188, 255],
#         [151, 188, 255],
#         [150, 188, 255],
#         ...,
#         [143, 183, 255],
#         [143, 183, 255],
#         [143, 183, 255]],
#
#        ...,
#
#        [[ 41,  53,  25],
#         [ 43,  56,  26],
#         [ 40,  53,  24],
#         ...,
#         [143, 115,  28],
#         [144, 130,  50],
#         [144, 130,  49]],
#
#        [[ 44,  57,  27],
#         [ 43,  56,  26],
#         [ 46,  61,  28],
#         ...,
#         [143, 115,  28],
#         [144, 131,  50],
#         [144, 130,  50]],
#
#        [[ 44,  57,  26],
#         [ 47,  62,  29],
#         [ 44,  58,  27],
#         ...,
#         [144, 131,  46],
#         [144, 131,  50],
#         [144, 131,  50]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(7.1926394), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[123, 156, 217],
#         [123, 157, 217],
#         [123, 157, 218],
#         ...,
#         [123, 159, 226],
#         [123, 159, 226],
#         [123, 159, 226]],
#
#        [[123, 156, 216],
#         [123, 156, 216],
#         [123, 157, 217],
#         ...,
#         [123, 159, 226],
#         [123, 159, 226],
#         [123, 159, 225]],
#
#        [[124, 156, 215],
#         [123, 156, 215],
#         [123, 156, 216],
#         ...,
#         [123, 159, 225],
#         [123, 159, 225],
#         [123, 159, 225]],
#
#        ...,
#
#        [[152, 146,  52],
#         [149, 145,  46],
#         [145, 141,  40],
#         ...,
#         [ 75,  98,  46],
#         [ 62,  81,  38],
#         [ 64,  84,  39]],
#
#        [[149, 145,  46],
#         [145, 141,  41],
#         [141, 137,  39],
#         ...,
#         [ 72,  94,  44],
#         [ 72,  94,  44],
#         [ 63,  83,  39]],
#
#        [[145, 141,  41],
#         [142, 138,  40],
#         [137, 133,  38],
#         ...,
#         [ 70,  92,  43],
#         [ 70,  91,  43],
#         [ 73,  96,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(10.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[148, 186, 255],
#         [148, 186, 255],
#         [148, 186, 255],
#         ...,
#         [143, 183, 255],
#         [143, 183, 255],
#         [144, 183, 255]],
#
#        [[149, 187, 255],
#         [149, 186, 255],
#         [148, 186, 255],
#         ...,
#         [143, 183, 255],
#         [144, 183, 255],
#         [144, 183, 255]],
#
#        [[149, 187, 255],
#         [149, 187, 255],
#         [149, 187, 255],
#         ...,
#         [144, 183, 255],
#         [144, 183, 255],
#         [144, 184, 255]],
#
#        ...,
#
#        [[174, 169,  49],
#         [174, 165,  46],
#         [172, 159,  54],
#         ...,
#         [145, 143,  53],
#         [146, 143,  47],
#         [147, 144,  48]],
#
#        [[166, 164,  45],
#         [167, 156,  41],
#         [163, 153,  50],
#         ...,
#         [143, 134,  45],
#         [146, 141,  49],
#         [147, 144,  48]],
#
#        [[159, 156,  42],
#         [159, 149,  38],
#         [156, 147,  47],
#         ...,
#         [143, 134,  45],
#         [143, 130,  41],
#         [147, 143,  50]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(7.1926394), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[126, 160, 222],
#         [126, 160, 222],
#         [126, 160, 223],
#         ...,
#         [125, 161, 228],
#         [125, 161, 228],
#         [125, 161, 227]],
#
#        [[126, 160, 221],
#         [126, 160, 222],
#         [126, 160, 222],
#         ...,
#         [125, 161, 228],
#         [125, 161, 227],
#         [125, 161, 227]],
#
#        [[126, 160, 221],
#         [126, 160, 221],
#         [126, 160, 222],
#         ...,
#         [125, 161, 227],
#         [125, 161, 227],
#         [125, 161, 227]],
#
#        ...,
#
#        [[156, 157,  62],
#         [156, 157,  62],
#         [156, 155,  65],
#         ...,
#         [ 86, 112,  53],
#         [ 75,  98,  46],
#         [ 72,  95,  44]],
#
#        [[156, 157,  62],
#         [156, 155,  66],
#         [156, 153,  62],
#         ...,
#         [ 77, 100,  47],
#         [ 74,  97,  46],
#         [ 80, 104,  49]],
#
#        [[156, 155,  66],
#         [156, 154,  65],
#         [156, 153,  62],
#         ...,
#         [ 75,  98,  46],
#         [ 78, 102,  48],
#         [ 82, 108,  51]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(10.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[148, 186, 255],
#         [147, 186, 255],
#         [147, 185, 255],
#         ...,
#         [144, 183, 255],
#         [144, 183, 255],
#         [144, 184, 255]],
#
#        [[148, 186, 255],
#         [148, 186, 255],
#         [147, 186, 255],
#         ...,
#         [144, 183, 255],
#         [144, 184, 255],
#         [145, 184, 255]],
#
#        [[149, 186, 255],
#         [148, 186, 255],
#         [148, 186, 255],
#         ...,
#         [144, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        ...,
#
#        [[207, 207,  91],
#         [207, 205,  87],
#         [205, 202,  83],
#         ...,
#         [133, 134,  46],
#         [135, 128,  36],
#         [137, 129,  36]],
#
#        [[207, 206,  84],
#         [207, 205,  81],
#         [205, 201,  78],
#         ...,
#         [133, 134,  46],
#         [134, 135,  47],
#         [137, 129,  36]],
#
#        [[205, 195,  65],
#         [205, 194,  65],
#         [205, 192,  64],
#         ...,
#         [134, 134,  49],
#         [134, 135,  47],
#         [135, 137,  47]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(7.1926394), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[128, 163, 226],
#         [128, 163, 226],
#         [128, 163, 227],
#         ...,
#         [127, 163, 230],
#         [127, 163, 230],
#         [127, 163, 230]],
#
#        [[128, 163, 226],
#         [128, 163, 226],
#         [128, 163, 226],
#         ...,
#         [127, 163, 230],
#         [127, 163, 230],
#         [127, 163, 229]],
#
#        [[128, 162, 225],
#         [128, 163, 225],
#         [128, 163, 226],
#         ...,
#         [127, 163, 229],
#         [127, 163, 229],
#         [127, 163, 229]],
#
#        ...,
#
#        [[157, 153,  45],
#         [157, 153,  45],
#         [157, 148,  42],
#         ...,
#         [ 79, 103,  48],
#         [ 76,  99,  47],
#         [ 78, 102,  48]],
#
#        [[157, 153,  45],
#         [157, 148,  42],
#         [157, 148,  42],
#         ...,
#         [ 80, 104,  49],
#         [ 78, 103,  48],
#         [ 75,  99,  46]],
#
#        [[157, 148,  42],
#         [157, 148,  42],
#         [157, 148,  42],
#         ...,
#         [ 75,  98,  46],
#         [ 80, 105,  50],
#         [ 81, 106,  50]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(10.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[147, 186, 255],
#         [147, 185, 255],
#         [147, 185, 255],
#         ...,
#         [144, 183, 255],
#         [144, 183, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [147, 186, 255],
#         [147, 185, 255],
#         ...,
#         [144, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [148, 186, 255],
#         [148, 186, 255],
#         ...,
#         [145, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        ...,
#
#        [[206, 196,  53],
#         [190, 168,  44],
#         [188, 172,  53],
#         ...,
#         [125, 118,  33],
#         [126, 120,  34],
#         [127, 120,  34]],
#
#        [[204, 195,  48],
#         [190, 168,  42],
#         [189, 173,  51],
#         ...,
#         [125, 124,  45],
#         [126, 120,  34],
#         [127, 120,  34]],
#
#        [[200, 189,  43],
#         [189, 163,  39],
#         [190, 173,  54],
#         ...,
#         [125, 124,  45],
#         [125, 125,  45],
#         [127, 120,  34]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[130, 165, 229],
#         [130, 165, 230],
#         [129, 165, 230],
#         ...,
#         [128, 165, 232],
#         [129, 165, 232],
#         [129, 165, 232]],
#
#        [[130, 165, 229],
#         [130, 165, 229],
#         [130, 165, 229],
#         ...,
#         [129, 165, 232],
#         [129, 165, 232],
#         [129, 165, 231]],
#
#        [[130, 165, 228],
#         [130, 165, 229],
#         [130, 165, 229],
#         ...,
#         [129, 165, 232],
#         [129, 165, 231],
#         [129, 165, 231]],
#
#        ...,
#
#        [[156, 155,  47],
#         [156, 155,  47],
#         [157, 153,  45],
#         ...,
#         [ 88, 116,  54],
#         [ 76,  99,  47],
#         [ 79, 104,  49]],
#
#        [[156, 155,  47],
#         [157, 148,  42],
#         [157, 153,  45],
#         ...,
#         [ 88, 116,  54],
#         [ 89, 117,  55],
#         [ 78, 102,  48]],
#
#        [[157, 148,  42],
#         [157, 148,  42],
#         [156, 151,  43],
#         ...,
#         [ 79, 103,  48],
#         [ 80, 105,  49],
#         [ 84, 110,  52]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[147, 185, 255],
#         [147, 185, 255],
#         [147, 185, 255],
#         ...,
#         [144, 183, 255],
#         [144, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [147, 186, 255],
#         [147, 185, 255],
#         ...,
#         [144, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [148, 186, 255],
#         [147, 186, 255],
#         ...,
#         [145, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        ...,
#
#        [[206, 207,  67],
#         [206, 205,  69],
#         [205, 204,  71],
#         ...,
#         [119, 117,  45],
#         [120, 114,  32],
#         [122, 115,  32]],
#
#        [[207, 205,  63],
#         [207, 205,  67],
#         [207, 204,  70],
#         ...,
#         [118, 116,  44],
#         [119, 118,  44],
#         [121, 114,  32]],
#
#        [[207, 202,  60],
#         [207, 202,  62],
#         [207, 202,  65],
#         ...,
#         [118, 117,  49],
#         [118, 117,  43],
#         [119, 118,  44]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[131, 167, 232],
#         [131, 167, 232],
#         [131, 167, 233],
#         ...,
#         [130, 167, 235],
#         [130, 167, 234],
#         [130, 167, 234]],
#
#        [[132, 167, 232],
#         [131, 167, 232],
#         [131, 167, 232],
#         ...,
#         [130, 167, 234],
#         [130, 167, 234],
#         [130, 167, 234]],
#
#        [[132, 167, 231],
#         [132, 167, 231],
#         [131, 167, 232],
#         ...,
#         [130, 167, 234],
#         [131, 167, 234],
#         [141, 167, 213]],
#
#        ...,
#
#        [[156, 156,  50],
#         [156, 156,  50],
#         [156, 156,  50],
#         ...,
#         [ 83, 108,  51],
#         [ 81, 106,  50],
#         [ 86, 113,  53]],
#
#        [[156, 156,  50],
#         [156, 156,  50],
#         [157, 148,  42],
#         ...,
#         [ 77, 101,  47],
#         [ 82, 108,  51],
#         [ 79, 103,  48]],
#
#        [[156, 156,  50],
#         [157, 148,  42],
#         [157, 148,  42],
#         ...,
#         [102, 134,  63],
#         [ 78, 102,  48],
#         [ 87, 113,  53]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[147, 185, 255],
#         [147, 185, 255],
#         [147, 185, 255],
#         ...,
#         [144, 183, 255],
#         [144, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [147, 186, 255],
#         [147, 185, 255],
#         ...,
#         [144, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [148, 186, 255],
#         [147, 186, 255],
#         ...,
#         [145, 184, 255],
#         [145, 184, 255],
#         [146, 184, 255]],
#
#        ...,
#
#        [[207, 197,  66],
#         [207, 197,  63],
#         [190, 166,  46],
#         ...,
#         [112, 111,  51],
#         [113, 112,  49],
#         [114, 113,  49]],
#
#        [[204, 197,  54],
#         [203, 196,  48],
#         [190, 167,  38],
#         ...,
#         [111, 111,  51],
#         [112, 112,  52],
#         [114, 113,  49]],
#
#        [[207, 201,  56],
#         [207, 201,  54],
#         [189, 168,  41],
#         ...,
#         [111, 110,  49],
#         [111, 111,  51],
#         [113, 112,  52]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[157, 156,  68],
#         [157, 156,  68],
#         [157, 156,  68],
#         ...,
#         [131, 169, 237],
#         [132, 169, 236],
#         [132, 169, 236]],
#
#        [[157, 156,  68],
#         [157, 156,  68],
#         [157, 156,  68],
#         ...,
#         [132, 169, 236],
#         [132, 169, 236],
#         [132, 169, 236]],
#
#        [[157, 156,  68],
#         [157, 156,  68],
#         [157, 156,  68],
#         ...,
#         [132, 169, 236],
#         [132, 169, 236],
#         [143, 170, 218]],
#
#        ...,
#
#        [[156, 156,  55],
#         [156, 156,  55],
#         [155, 155,  55],
#         ...,
#         [ 77, 101,  47],
#         [ 86, 113,  53],
#         [ 83, 108,  51]],
#
#        [[156, 156,  55],
#         [155, 155,  55],
#         [155, 155,  55],
#         ...,
#         [ 94, 123,  58],
#         [ 77, 101,  47],
#         [ 88, 115,  54]],
#
#        [[155, 155,  55],
#         [155, 155,  55],
#         [155, 155,  55],
#         ...,
#         [ 91, 119,  56],
#         [ 77, 100,  47],
#         [ 82, 107,  51]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[147, 185, 255],
#         [147, 185, 255],
#         [147, 185, 255],
#         ...,
#         [144, 183, 255],
#         [144, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [147, 186, 255],
#         [147, 185, 255],
#         ...,
#         [144, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [148, 186, 255],
#         [147, 186, 255],
#         ...,
#         [145, 184, 255],
#         [145, 184, 255],
#         [146, 184, 255]],
#
#        ...,
#
#        [[206, 199,  73],
#         [207, 206,  89],
#         [205, 205,  68],
#         ...,
#         [103, 103,  34],
#         [103, 104,  40],
#         [104, 104,  40]],
#
#        [[207, 206,  89],
#         [207, 206,  89],
#         [205, 205,  68],
#         ...,
#         [103, 103,  34],
#         [104, 103,  34],
#         [104, 104,  40]],
#
#        [[207, 206,  89],
#         [207, 206,  89],
#         [205, 205,  66],
#         ...,
#         [ 97,  87,  25],
#         [104, 103,  34],
#         [105, 104,  34]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[144, 130,  45],
#         [144, 130,  45],
#         [144, 130,  45],
#         ...,
#         [133, 170, 238],
#         [133, 170, 238],
#         [133, 170, 238]],
#
#        [[144, 130,  45],
#         [144, 130,  45],
#         [144, 130,  45],
#         ...,
#         [133, 170, 238],
#         [133, 170, 238],
#         [133, 170, 238]],
#
#        [[144, 130,  49],
#         [144, 130,  45],
#         [144, 130,  45],
#         ...,
#         [133, 170, 238],
#         [133, 170, 238],
#         [146, 173, 221]],
#
#        ...,
#
#        [[144, 131,  40],
#         [144, 131,  40],
#         [144, 131,  40],
#         ...,
#         [ 80, 104,  49],
#         [ 93, 121,  57],
#         [ 79, 104,  49]],
#
#        [[144, 131,  40],
#         [144, 131,  40],
#         [144, 130,  45],
#         ...,
#         [102, 133,  62],
#         [ 85, 111,  52],
#         [ 74,  96,  45]],
#
#        [[144, 131,  40],
#         [144, 130,  45],
#         [144, 130,  45],
#         ...,
#         [ 74,  97,  46],
#         [100, 131,  62],
#         [ 85, 111,  52]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[147, 185, 255],
#         [147, 185, 255],
#         [147, 185, 255],
#         ...,
#         [144, 183, 255],
#         [144, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [147, 186, 255],
#         [147, 185, 255],
#         ...,
#         [144, 184, 255],
#         [145, 184, 255],
#         [145, 184, 255]],
#
#        [[148, 186, 255],
#         [148, 186, 255],
#         [147, 186, 255],
#         ...,
#         [145, 184, 255],
#         [145, 184, 255],
#         [146, 184, 255]],
#
#        ...,
#
#        [[206, 201,  63],
#         [206, 201,  63],
#         [207, 201,  58],
#         ...,
#         [ 98,  98,  42],
#         [ 99,  99,  43],
#         [100,  99,  43]],
#
#        [[206, 201,  63],
#         [206, 201,  63],
#         [206, 201,  58],
#         ...,
#         [ 98,  98,  42],
#         [ 99,  99,  43],
#         [100,  99,  43]],
#
#        [[206, 201,  63],
#         [206, 201,  63],
#         [206, 201,  58],
#         ...,
#         [ 98,  98,  42],
#         [ 99,  99,  43],
#         [100,  99,  43]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[144, 126,  35],
#         [154, 118,  30],
#         [154, 118,  30],
#         ...,
#         [134, 171, 240],
#         [134, 172, 240],
#         [134, 172, 240]],
#
#        [[144, 126,  35],
#         [144, 126,  35],
#         [154, 118,  30],
#         ...,
#         [134, 172, 240],
#         [134, 172, 240],
#         [134, 172, 239]],
#
#        [[144, 126,  35],
#         [144, 126,  35],
#         [144, 126,  35],
#         ...,
#         [134, 172, 240],
#         [134, 172, 239],
#         [148, 176, 225]],
#
#        ...,
#
#        [[142, 116,  29],
#         [142, 116,  29],
#         [142, 116,  29],
#         ...,
#         [ 82, 108,  51],
#         [ 82, 108,  51],
#         [ 82, 108,  51]],
#
#        [[142, 116,  29],
#         [142, 116,  29],
#         [143, 115,  28],
#         ...,
#         [ 79, 103,  48],
#         [ 82, 108,  51],
#         [ 82, 108,  51]],
#
#        [[142, 116,  29],
#         [143, 115,  28],
#         [143, 115,  28],
#         ...,
#         [ 71,  93,  44],
#         [ 89, 116,  55],
#         [ 80, 104,  49]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[188, 162,  38],
#         [188, 162,  38],
#         [190, 172,  53],
#         ...,
#         [135, 119,  30],
#         [101,  92,  27],
#         [101,  92,  27]],
#
#        [[188, 162,  38],
#         [188, 162,  38],
#         [190, 172,  53],
#         ...,
#         [134, 119,  30],
#         [101,  92,  27],
#         [100,  92,  27]],
#
#        [[188, 162,  38],
#         [188, 162,  38],
#         [190, 172,  53],
#         ...,
#         [133, 118,  30],
#         [100,  91,  27],
#         [101,  91,  28]],
#
#        ...,
#
#        [[189, 167,  42],
#         [189, 167,  42],
#         [188, 172,  50],
#         ...,
#         [113,  97,  23],
#         [ 87,  79,  24],
#         [ 86,  79,  23]],
#
#        [[189, 167,  42],
#         [189, 167,  42],
#         [188, 172,  50],
#         ...,
#         [113,  97,  23],
#         [ 87,  79,  24],
#         [ 87,  79,  24]],
#
#        [[189, 167,  42],
#         [188, 162,  38],
#         [189, 172,  53],
#         ...,
#         [114, 100,  28],
#         [ 87,  79,  24],
#         [ 87,  79,  24]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[157, 150,  48],
#         [157, 150,  48],
#         [148, 136,  50],
#         ...,
#         [135, 173, 242],
#         [135, 173, 241],
#         [135, 173, 241]],
#
#        [[157, 150,  48],
#         [157, 150,  48],
#         [157, 150,  48],
#         ...,
#         [135, 173, 241],
#         [135, 173, 241],
#         [136, 173, 241]],
#
#        [[157, 150,  48],
#         [157, 150,  48],
#         [157, 150,  48],
#         ...,
#         [135, 173, 241],
#         [136, 173, 241],
#         [150, 179, 228]],
#
#        ...,
#
#        [[156, 147,  47],
#         [156, 147,  47],
#         [156, 147,  47],
#         ...,
#         [ 79, 103,  48],
#         [ 78, 103,  48],
#         [ 82, 108,  51]],
#
#        [[156, 147,  47],
#         [156, 147,  47],
#         [153, 137,  39],
#         ...,
#         [ 71,  93,  44],
#         [ 89, 116,  55],
#         [ 89, 116,  55]],
#
#        [[156, 147,  47],
#         [153, 137,  39],
#         [153, 137,  39],
#         ...,
#         [ 83, 109,  51],
#         [ 71,  93,  44],
#         [ 89, 116,  55]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[188, 171,  55],
#         [204, 202,  69],
#         [203, 202,  69],
#         ...,
#         [ 90,  82,  26],
#         [ 90,  82,  26],
#         [ 90,  82,  26]],
#
#        [[188, 171,  55],
#         [204, 202,  69],
#         [203, 202,  69],
#         ...,
#         [ 90,  82,  26],
#         [ 89,  81,  26],
#         [ 91,  82,  23]],
#
#        [[188, 171,  55],
#         [204, 202,  69],
#         [203, 202,  69],
#         ...,
#         [ 89,  81,  26],
#         [ 91,  82,  23],
#         [ 91,  82,  23]],
#
#        ...,
#
#        [[185, 169,  59],
#         [200, 201,  79],
#         [199, 200,  78],
#         ...,
#         [ 89,  81,  28],
#         [ 89,  81,  31],
#         [ 89,  81,  31]],
#
#        [[185, 169,  59],
#         [200, 201,  79],
#         [199, 200,  78],
#         ...,
#         [ 89,  81,  28],
#         [ 89,  81,  29],
#         [ 89,  81,  31]],
#
#        [[185, 169,  59],
#         [201, 199,  68],
#         [200, 198,  67],
#         ...,
#         [ 89,  81,  28],
#         [ 89,  81,  29],
#         [ 89,  81,  29]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[157, 150,  48],
#         [157, 150,  48],
#         [148, 136,  50],
#         ...,
#         [136, 174, 243],
#         [136, 174, 243],
#         [136, 174, 243]],
#
#        [[157, 150,  48],
#         [157, 150,  48],
#         [157, 150,  48],
#         ...,
#         [136, 174, 243],
#         [136, 174, 243],
#         [136, 174, 242]],
#
#        [[157, 150,  48],
#         [157, 150,  48],
#         [157, 150,  48],
#         ...,
#         [136, 174, 243],
#         [137, 174, 242],
#         [152, 181, 230]],
#
#        ...,
#
#        [[156, 147,  47],
#         [156, 147,  47],
#         [156, 147,  47],
#         ...,
#         [ 89, 116,  55],
#         [ 80, 105,  49],
#         [ 80, 105,  49]],
#
#        [[156, 147,  47],
#         [156, 147,  47],
#         [153, 137,  39],
#         ...,
#         [ 71,  93,  44],
#         [ 89, 116,  55],
#         [ 89, 116,  55]],
#
#        [[156, 147,  47],
#         [153, 137,  39],
#         [153, 137,  39],
#         ...,
#         [ 83, 109,  51],
#         [ 71,  93,  44],
#         [ 89, 116,  55]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[199, 197,  65],
#         [198, 196,  65],
#         [197, 195,  64],
#         ...,
#         [ 92,  83,  23],
#         [ 92,  84,  23],
#         [ 84,  67,  18]],
#
#        [[198, 197,  65],
#         [197, 195,  65],
#         [196, 194,  64],
#         ...,
#         [ 92,  83,  23],
#         [ 84,  67,  17],
#         [ 84,  67,  18]],
#
#        [[198, 196,  65],
#         [196, 195,  64],
#         [195, 194,  64],
#         ...,
#         [ 84,  67,  17],
#         [ 84,  67,  17],
#         [ 84,  67,  18]],
#
#        ...,
#
#        [[193, 193,  74],
#         [191, 192,  74],
#         [190, 191,  73],
#         ...,
#         [ 99,  98,  45],
#         [ 99,  98,  47],
#         [ 99,  99,  47]],
#
#        [[193, 193,  74],
#         [191, 192,  74],
#         [190, 191,  73],
#         ...,
#         [ 99,  98,  45],
#         [ 99,  99,  45],
#         [ 99,  99,  47]],
#
#        [[193, 193,  74],
#         [191, 192,  74],
#         [190, 191,  73],
#         ...,
#         [ 99,  98,  45],
#         [ 99,  99,  45],
#         [ 99,  99,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(8.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[157, 150,  50],
#         [157, 150,  48],
#         [148, 136,  50],
#         ...,
#         [137, 175, 244],
#         [137, 175, 244],
#         [137, 175, 244]],
#
#        [[157, 150,  50],
#         [157, 150,  48],
#         [157, 150,  48],
#         ...,
#         [137, 175, 244],
#         [137, 175, 244],
#         [137, 175, 244]],
#
#        [[157, 150,  50],
#         [157, 150,  48],
#         [157, 150,  48],
#         ...,
#         [137, 175, 244],
#         [137, 175, 244],
#         [154, 183, 233]],
#
#        ...,
#
#        [[157, 152,  53],
#         [156, 147,  47],
#         [156, 147,  47],
#         ...,
#         [ 89, 116,  55],
#         [ 80, 105,  49],
#         [ 80, 105,  49]],
#
#        [[157, 152,  53],
#         [156, 147,  47],
#         [153, 137,  39],
#         ...,
#         [ 71,  93,  44],
#         [ 89, 116,  55],
#         [ 80, 104,  49]],
#
#        [[157, 152,  53],
#         [153, 137,  39],
#         [153, 137,  39],
#         ...,
#         [ 89, 117,  55],
#         [ 95, 124,  58],
#         [ 84, 110,  52]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(11.192639), 'saturation': array(20.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[195, 194,  64],
#         [194, 190,  62],
#         [193, 188,  62],
#         ...,
#         [ 85,  68,  18],
#         [ 85,  68,  18],
#         [ 85,  68,  18]],
#
#        [[195, 193,  64],
#         [193, 189,  62],
#         [192, 188,  62],
#         ...,
#         [ 85,  68,  18],
#         [ 85,  68,  18],
#         [ 85,  68,  18]],
#
#        [[194, 192,  64],
#         [193, 188,  62],
#         [192, 187,  61],
#         ...,
#         [ 85,  68,  18],
#         [ 85,  68,  18],
#         [100,  92,  39]],
#
#        ...,
#
#        [[189, 190,  73],
#         [188, 188,  73],
#         [187, 187,  72],
#         ...,
#         [100,  99,  47],
#         [100,  99,  47],
#         [101, 100,  47]],
#
#        [[189, 190,  73],
#         [188, 188,  73],
#         [187, 187,  72],
#         ...,
#         [100,  99,  47],
#         [100,  99,  47],
#         [101, 100,  47]],
#
#        [[189, 190,  73],
#         [188, 188,  73],
#         [187, 187,  72],
#         ...,
#         [100,  99,  47],
#         [100,  99,  47],
# ...
# {'agent_0': {'pov': array([[[ 86,  85,  34],
#         [ 85,  82,  28],
#         [ 85,  82,  28],
#         ...,
#         [135, 132,  47],
#         [135, 132,  47],
#         [134, 134,  45]],
#
#        [[ 86,  85,  34],
#         [ 86,  85,  34],
#         [ 85,  82,  28],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        [[ 86,  86,  34],
#         [ 86,  85,  34],
#         [ 85,  85,  33],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        ...,
#
#        [[200, 195,  60],
#         [198, 194,  59],
#         [197, 192,  59],
#         ...,
#         [136, 135,  57],
#         [135, 134,  51],
#         [136, 134,  51]],
#
#        [[198, 194,  59],
#         [197, 192,  59],
#         [195, 191,  61],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 134,  51]],
#
#        [[197, 192,  62],
#         [195, 191,  61],
#         [194, 189,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 135,  57]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(1.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [145, 184, 255],
#         [146, 184, 255],
#         [146, 185, 255]],
#
#        [[156, 156,  56],
#         [157, 148,  42],
#         [157, 149,  43],
#         ...,
#         [146, 184, 255],
#         [146, 185, 255],
#         [147, 185, 255]],
#
#        [[156, 157,  62],
#         [156, 156,  56],
#         [157, 149,  43],
#         ...,
#         [169, 201, 255],
#         [147, 185, 255],
#         [147, 185, 255]],
#
#        ...,
#
#        [[147, 146,  51],
#         [144, 143,  50],
#         [141, 140,  49],
#         ...,
#         [ 85, 111,  52],
#         [ 94, 123,  58],
#         [ 67,  87,  41]],
#
#        [[145, 144,  51],
#         [143, 142,  50],
#         [141, 138,  48],
#         ...,
#         [104, 136,  64],
#         [ 85, 111,  52],
#         [ 94, 123,  58]],
#
#        [[143, 143,  50],
#         [142, 140,  49],
#         [139, 136,  48],
#         ...,
#         [ 66,  87,  41],
#         [104, 136,  64],
#         [ 72,  95,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(7.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[ 86,  85,  34],
#         [ 85,  82,  28],
#         [ 85,  82,  28],
#         ...,
#         [135, 132,  47],
#         [135, 132,  47],
#         [134, 134,  45]],
#
#        [[ 86,  85,  34],
#         [ 85,  85,  34],
#         [ 85,  82,  28],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        [[ 86,  86,  34],
#         [ 86,  85,  34],
#         [ 85,  85,  33],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        ...,
#
#        [[200, 195,  60],
#         [198, 194,  59],
#         [197, 192,  59],
#         ...,
#         [136, 135,  57],
#         [135, 134,  51],
#         [136, 134,  51]],
#
#        [[198, 194,  59],
#         [197, 192,  59],
#         [195, 191,  61],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 134,  51]],
#
#        [[197, 192,  62],
#         [195, 191,  61],
#         [194, 189,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 135,  57]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(1.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [145, 184, 255],
#         [146, 184, 255],
#         [146, 185, 255]],
#
#        [[156, 156,  56],
#         [157, 148,  42],
#         [157, 149,  43],
#         ...,
#         [146, 184, 255],
#         [146, 185, 255],
#         [147, 185, 255]],
#
#        [[156, 157,  62],
#         [156, 156,  56],
#         [157, 149,  43],
#         ...,
#         [169, 201, 255],
#         [147, 185, 255],
#         [147, 185, 255]],
#
#        ...,
#
#        [[146, 146,  51],
#         [144, 143,  50],
#         [141, 139,  49],
#         ...,
#         [ 85, 111,  52],
#         [ 94, 123,  58],
#         [ 67,  87,  41]],
#
#        [[145, 144,  51],
#         [143, 142,  50],
#         [141, 138,  48],
#         ...,
#         [104, 136,  64],
#         [ 85, 111,  52],
#         [ 94, 123,  58]],
#
#        [[143, 143,  50],
#         [141, 140,  49],
#         [139, 136,  47],
#         ...,
#         [ 66,  87,  41],
#         [104, 136,  64],
#         [ 72,  95,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(7.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[ 86,  85,  34],
#         [ 85,  82,  28],
#         [ 85,  82,  28],
#         ...,
#         [135, 132,  47],
#         [135, 132,  47],
#         [134, 134,  45]],
#
#        [[ 86,  85,  34],
#         [ 85,  85,  34],
#         [ 85,  82,  28],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        [[ 86,  86,  34],
#         [ 86,  85,  34],
#         [ 85,  85,  33],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        ...,
#
#        [[200, 195,  60],
#         [198, 194,  59],
#         [197, 192,  59],
#         ...,
#         [136, 135,  57],
#         [135, 134,  51],
#         [136, 134,  51]],
#
#        [[198, 193,  59],
#         [197, 192,  59],
#         [195, 191,  61],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 134,  51]],
#
#        [[197, 192,  62],
#         [195, 191,  61],
#         [194, 189,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 135,  57]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(1.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [145, 184, 255],
#         [146, 184, 255],
#         [146, 185, 255]],
#
#        [[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [146, 184, 255],
#         [146, 185, 255],
#         [147, 185, 255]],
#
#        [[156, 156,  56],
#         [156, 156,  56],
#         [157, 149,  43],
#         ...,
#         [169, 201, 255],
#         [147, 185, 255],
#         [147, 185, 255]],
#
#        ...,
#
#        [[146, 146,  51],
#         [143, 143,  50],
#         [141, 139,  49],
#         ...,
#         [ 85, 111,  52],
#         [ 94, 123,  58],
#         [ 67,  87,  41]],
#
#        [[145, 144,  51],
#         [143, 142,  50],
#         [140, 138,  48],
#         ...,
#         [104, 136,  64],
#         [ 94, 123,  58],
#         [ 94, 123,  58]],
#
#        [[144, 143,  50],
#         [141, 140,  49],
#         [139, 136,  47],
#         ...,
#         [ 66,  87,  41],
#         [104, 136,  64],
#         [ 72,  95,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(7.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[ 86,  85,  34],
#         [ 85,  82,  28],
#         [ 85,  82,  28],
#         ...,
#         [135, 132,  47],
#         [135, 132,  47],
#         [134, 134,  45]],
#
#        [[ 86,  85,  34],
#         [ 85,  85,  34],
#         [ 85,  82,  28],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        [[ 86,  85,  34],
#         [ 86,  85,  34],
#         [ 85,  85,  33],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [134, 134,  45]],
#
#        ...,
#
#        [[200, 195,  60],
#         [198, 194,  59],
#         [197, 192,  59],
#         ...,
#         [136, 135,  57],
#         [135, 134,  51],
#         [136, 134,  51]],
#
#        [[198, 193,  59],
#         [197, 192,  59],
#         [195, 191,  61],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 134,  51]],
#
#        [[197, 192,  62],
#         [195, 191,  61],
#         [194, 189,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 135,  57]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(1.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [145, 184, 255],
#         [146, 184, 255],
#         [146, 185, 255]],
#
#        [[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [146, 184, 255],
#         [146, 185, 255],
#         [147, 185, 255]],
#
#        [[156, 156,  56],
#         [156, 156,  55],
#         [157, 149,  43],
#         ...,
#         [169, 201, 255],
#         [147, 185, 255],
#         [147, 185, 255]],
#
#        ...,
#
#        [[146, 145,  51],
#         [144, 141,  51],
#         [140, 139,  49],
#         ...,
#         [ 85, 111,  52],
#         [ 94, 123,  58],
#         [ 67,  87,  41]],
#
#        [[144, 144,  51],
#         [142, 140,  50],
#         [140, 137,  48],
#         ...,
#         [104, 136,  64],
#         [ 72,  95,  45],
#         [ 94, 123,  58]],
#
#        [[144, 143,  50],
#         [140, 139,  49],
#         [138, 136,  47],
#         ...,
#         [ 66,  87,  41],
#         [104, 136,  64],
#         [ 72,  95,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(7.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[ 86,  85,  34],
#         [ 85,  82,  28],
#         [ 85,  82,  28],
#         ...,
#         [135, 132,  47],
#         [135, 132,  47],
#         [135, 135,  45]],
#
#        [[ 86,  85,  34],
#         [ 85,  85,  34],
#         [ 85,  82,  28],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [135, 135,  45]],
#
#        [[ 86,  85,  34],
#         [ 86,  85,  34],
#         [ 85,  85,  33],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [135, 135,  45]],
#
#        ...,
#
#        [[200, 195,  60],
#         [198, 193,  59],
#         [197, 192,  59],
#         ...,
#         [136, 135,  57],
#         [135, 134,  51],
#         [136, 134,  51]],
#
#        [[198, 193,  59],
#         [197, 192,  59],
#         [195, 191,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 134,  51]],
#
#        [[197, 192,  62],
#         [195, 191,  61],
#         [194, 189,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 135,  57]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(1.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [145, 184, 255],
#         [146, 184, 255],
#         [146, 185, 255]],
#
#        [[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [146, 184, 255],
#         [146, 185, 255],
#         [147, 185, 255]],
#
#        [[156, 156,  56],
#         [156, 156,  55],
#         [157, 149,  43],
#         ...,
#         [169, 201, 255],
#         [147, 185, 255],
#         [147, 185, 255]],
#
#        ...,
#
#        [[146, 145,  51],
#         [143, 142,  50],
#         [140, 139,  49],
#         ...,
#         [ 85, 111,  52],
#         [ 94, 123,  58],
#         [106, 139,  65]],
#
#        [[144, 143,  51],
#         [142, 140,  49],
#         [140, 137,  48],
#         ...,
#         [104, 136,  64],
#         [ 72,  95,  45],
#         [ 94, 123,  58]],
#
#        [[144, 142,  50],
#         [140, 138,  49],
#         [138, 135,  47],
#         ...,
#         [ 66,  87,  41],
#         [104, 136,  64],
#         [ 72,  95,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(7.), 'score': array(0), 'xp': array(0)}}}
# {'agent_0': {'pov': array([[[ 86,  85,  34],
#         [ 85,  82,  28],
#         [ 85,  82,  28],
#         ...,
#         [135, 132,  47],
#         [135, 132,  47],
#         [135, 135,  45]],
#
#        [[ 86,  85,  34],
#         [ 85,  85,  33],
#         [ 85,  82,  28],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [135, 135,  45]],
#
#        [[ 86,  85,  34],
#         [ 86,  85,  34],
#         [ 85,  85,  33],
#         ...,
#         [134, 134,  45],
#         [134, 134,  45],
#         [135, 135,  45]],
#
#        ...,
#
#        [[200, 195,  59],
#         [198, 193,  59],
#         [197, 192,  59],
#         ...,
#         [136, 135,  57],
#         [135, 134,  51],
#         [136, 134,  51]],
#
#        [[198, 193,  59],
#         [197, 192,  59],
#         [195, 191,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 134,  51]],
#
#        [[197, 192,  62],
#         [195, 191,  61],
#         [194, 189,  58],
#         ...,
#         [136, 135,  57],
#         [136, 135,  57],
#         [136, 135,  57]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(1.), 'score': array(0), 'xp': array(0)}}, 'agent_1': {'pov': array([[[157, 148,  42],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [145, 184, 255],
#         [146, 184, 255],
#         [146, 185, 255]],
#
#        [[156, 156,  56],
#         [157, 148,  42],
#         [156, 150,  43],
#         ...,
#         [146, 184, 255],
#         [146, 185, 255],
#         [147, 185, 255]],
#
#        [[156, 156,  56],
#         [156, 156,  55],
#         [157, 149,  43],
#         ...,
#         [169, 201, 255],
#         [147, 185, 255],
#         [147, 185, 255]],
#
#        ...,
#
#        [[145, 145,  51],
#         [143, 141,  50],
#         [140, 138,  49],
#         ...,
#         [ 85, 111,  52],
#         [ 94, 123,  58],
#         [106, 139,  65]],
#
#        [[144, 143,  50],
#         [141, 140,  49],
#         [140, 137,  47],
#         ...,
#         [104, 136,  64],
#         [ 72,  95,  45],
#         [ 94, 123,  58]],
#
#        [[143, 142,  50],
#         [140, 138,  49],
#         [138, 135,  47],
#         ...,
#         [ 66,  87,  41],
#         [104, 136,  64],
#         [ 72,  95,  45]]], dtype=uint8), 'life_stats': {'air': array(300), 'food': array(20), 'is_alive': array(True), 'life': array(20.), 'saturation': array(7.), 'score': array(0), 'xp': array(0)}}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/yj/w4y5s1bd3z55tr6692mv9g5c0000gn/T/ipykernel_68990/4223185435.py in <module>
#      48             # print(str(steps) + " actions: " + str(actions))
#      49
# ---> 50             obs, reward, done, info = env.step(actions)
#      51
#      52             print(obs)
#
# ~/.local/lib/python3.9/site-packages/minerl/env/_multiagent.py in step(self, actions)
#     291
#     292                         # Receive the observation.
# --> 293                         obs = instance.client_socket_recv_message()
#     294
#     295                         # Receive reward done and sent.
#
# ~/.local/lib/python3.9/site-packages/minerl/env/malmo.py in client_socket_recv_message(self)
#     456
#     457     def client_socket_recv_message(self):
# --> 458         return comms.recv_message(self.client_socket)
#     459
#     460     def client_socket_close(self):
#
# ~/.local/lib/python3.9/site-packages/minerl/env/comms.py in recv_message(sock)
#      61
#      62 def recv_message(sock):
# ---> 63     lengthbuf = recvall(sock, 4)
#      64     if not lengthbuf:
#      65         return None
#
# ~/.local/lib/python3.9/site-packages/minerl/env/comms.py in recvall(sock, count)
#      71     buf = b''
#      72     while count:
# ---> 73         newbuf = sock.recv(count)
#      74         if not newbuf:
#      75             return None
#
# KeyboardInterrupt:

# %%
env.reset()
# Out:
# MineRL agent is public, connect on port 58842 with Minecraft 1.11
# No air observation! Yielding default value 300 for air
# No food observation! Yielding default value 20 for food
# No is_alive observation! Yielding default value True for is_alive
# No life observation! Yielding default value 20 for life
# No saturation observation! Yielding default value 5.0 for saturation
# No score observation! Yielding default value 0 for score
# No xp observation! Yielding default value 0 for xp
# No air observation! Yielding default value 300 for air
# No food observation! Yielding default value 20 for food
# No is_alive observation! Yielding default value True for is_alive
# No life observation! Yielding default value 20 for life
# No saturation observation! Yielding default value 5.0 for saturation
# No score observation! Yielding default value 0 for score
# No xp observation! Yielding default value 0 for xp
# {'agent_0': {'pov': array([[[ 43,  36, 101],
#           [ 43,  36, 101],
#           [ 43,  36, 101],
#           ...,
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122]],
#
#          [[ 43,  36, 101],
#           [ 43,  36, 101],
#           [ 43,  36, 101],
#           ...,
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122]],
#
#          [[ 43,  36, 101],
#           [ 43,  36, 101],
#           [ 43,  36, 101],
#           ...,
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122]],
#
#          ...,
#
#          [[ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           ...,
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122]],
#
#          [[ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           ...,
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122]],
#
#          [[ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           ...,
#           [ 52,  43, 122],
#           [ 52,  43, 122],
#           [ 52,  43, 122]]], dtype=uint8),
#   'life_stats': {'air': array(300),
#    'food': array(20),
#    'is_alive': array(True),
#    'life': array(20),
#    'saturation': array(5.),
#    'score': array(0),
#    'xp': array(0)}},
#  'agent_1': {'pov': array([[[107,  72,  33],
#           [107,  72,  33],
#           [107,  72,  33],
#           ...,
#           [107,  72,  33],
#           [107,  72,  33],
#           [107,  72,  33]],
#
#          [[107,  72,  33],
#           [107,  72,  33],
#           [107,  72,  33],
#           ...,
#           [107,  72,  33],
#           [107,  72,  33],
#           [107,  72,  33]],
#
#          [[107,  72,  33],
#           [107,  72,  33],
#           [107,  72,  33],
#           ...,
#           [107,  72,  33],
#           [107,  72,  33],
#           [107,  72,  33]],
#
#          ...,
#
#          [[169, 113,  53],
#           [169, 113,  53],
#           [169, 113,  53],
#           ...,
#           [102, 103,  75],
#           [102, 103,  75],
#           [102, 103,  75]],
#
#          [[169, 113,  53],
#           [169, 113,  53],
#           [169, 113,  53],
#           ...,
#           [102, 103,  75],
#           [102, 103,  75],
#           [102, 103,  75]],
#
#          [[169, 113,  53],
#           [169, 113,  53],
#           [169, 113,  53],
#           ...,
#           [102, 103,  75],
#           [102, 103,  75],
#           [102, 103,  75]]], dtype=uint8),
#   'life_stats': {'air': array(300),
#    'food': array(20),
#    'is_alive': array(True),
#    'life': array(20),
#    'saturation': array(5.),
#    'score': array(0),
#    'xp': array(0)}}}

# %%
done = False
actor_names = env.task.agent_names
# while not done:
    # steps += 1
    # env.render()

actions = env.action_space.no_op()
for agent in actions:
    actions[agent]["forward"] = 0.1
    actions[agent]["attack"] = 1
    actions[agent]["camera"] = [0, 0.1]
    # actions = env.action_space.sample()

    # print(str(steps) + " actions: " + str(actions))

    obs, reward, done, info = env.step(actions)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/yj/w4y5s1bd3z55tr6692mv9g5c0000gn/T/ipykernel_68990/1523151667.py in <module>
#      14     # print(str(steps) + " actions: " + str(actions))
#      15
# ---> 16     obs, reward, done, info = env.step(actions)
#      17
#
# ~/.local/lib/python3.9/site-packages/minerl/env/_multiagent.py in step(self, actions)
#     363                 self._last_step_time = time.time()
#     364         else:
# --> 365             raise RuntimeError("Attempted to step an environment server with done=True")
#     366
#     367         #  WE DON'T CURRENTLY PIPE OUT WHETHER EACH AGENT IS DONE
#
# RuntimeError: Attempted to step an environment server with done=True
